# %%
# data fromam: combine the multiple series called df

# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Name": ["Naveen", "Rahul", "Priya", "Anjali", "Kiran"],
    "Age": [20, 21, 19, 22, 20],
    "Marks": [85, 78, 92, 74, 88],
    "Branch": ["CSE", "ECE", "CSE", "ME", "CSE"]
}
df = pd.DataFrame(data)

# %%
df['Name']
# Out:
# 0    Naveen
# 1     Rahul
# 2     Priya
# 3    Anjali
# 4     Kiran
# Name: Name, dtype: object

# %%
df[['Name', 'Age']]
# Out:
#      Name  Age
# 0  Naveen   20
# 1   Rahul   21
# 2   Priya   19
# 3  Anjali   22
# 4   Kiran   20

# %%
df['city']=['m','b', 'h','d','r']

# %%
df['city']
# Out:
# 0    m
# 1    b
# 2    h
# 3    d
# 4    r
# Name: city, dtype: object

# %%
df
# Out:
#      Name  Age  Marks Branch city
# 0  Naveen   20     85    CSE    m
# 1   Rahul   21     78    ECE    b
# 2   Priya   19     92    CSE    h
# 3  Anjali   22     74     ME    d
# 4   Kiran   20     88    CSE    r

# %%
df.drop('city' , axis=1) # same but not achualy not dlete the data is df as in collumn
# Out:
#      Name  Age  Marks Branch
# 0  Naveen   20     85    CSE
# 1   Rahul   21     78    ECE
# 2   Priya   19     92    CSE
# 3  Anjali   22     74     ME
# 4   Kiran   20     88    CSE

# %%
df
# Out:
#      Name  Age  Marks Branch city
# 0  Naveen   20     85    CSE    m
# 1   Rahul   21     78    ECE    b
# 2   Priya   19     92    CSE    h
# 3  Anjali   22     74     ME    d
# 4   Kiran   20     88    CSE    r

# %%
df.drop('city',axis=1, inplace=True)# drop colleum with real data

# %%
df
# Out:
#      Name  Age  Marks Branch
# 0  Naveen   20     85    CSE
# 1   Rahul   21     78    ECE
# 2   Priya   19     92    CSE
# 3  Anjali   22     74     ME
# 4   Kiran   20     88    CSE

# %%
# drop row
df.drop(0, axis=0)  # o is row and 1 is columen
# Out:
#      Name  Age  Marks Branch
# 1   Rahul   21     78    ECE
# 2   Priya   19     92    CSE
# 3  Anjali   22     74     ME
# 4   Kiran   20     88    CSE

# %%
df
# Out:
#      Name  Age  Marks Branch
# 0  Naveen   20     85    CSE
# 1   Rahul   21     78    ECE
# 2   Priya   19     92    CSE
# 3  Anjali   22     74     ME
# 4   Kiran   20     88    CSE

# %%
# accesing rwo using loc
df.loc[0] #loc is location
# Out:
# Name      Naveen
# Age           20
# Marks         85
# Branch       CSE
# Name: 0, dtype: object

# %%
df.loc[[1,0]]
# Out:
#      Name  Age  Marks Branch
# 1   Rahul   21     78    ECE
# 0  Naveen   20     85    CSE

# %%
# selecting the subset of row and columns
df.loc[[0,1]][["Branch","Marks"]]
# Out:
#   Branch  Marks
# 0    CSE     85
# 1    ECE     78

# %%
df.loc[[3,4]][["Name","Age"]]
# Out:
#      Name  Age
# 3  Anjali   22
# 4   Kiran   20

# %%
# condition selection 
<,>

# %%
df[df["Age"]>20]
# Out:
#      Name  Age  Marks Branch
# 1   Rahul   21     78    ECE
# 3  Anjali   22     74     ME

# %%
df
# Out:
#      Name  Age  Marks Branch
# 0  Naveen   20     85    CSE
# 1   Rahul   21     78    ECE
# 2   Priya   19     92    CSE
# 3  Anjali   22     74     ME
# 4   Kiran   20     88    CSE

# %%
df[(df["Age"] > 20) & (df["Marks"] > 80)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Marks, Branch]
# Index: []
