# %%
# mising data

# %%
import numpy as np
import pandas as pd

# %%
data = {

    "Name": ["Naveen", "Rahul", "Priya", "Anjali", "Kiran"],
    "Age": [20, None, 19, 22, None],
    "Marks": [85, 78, None, 74, 88],
    "Branch": ["CSE", "ECE", None, "ME", "CSE"]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name   Age  Marks Branch
# 0  Naveen  20.0   85.0    CSE
# 1   Rahul   NaN   78.0    ECE
# 2   Priya  19.0    NaN   None
# 3  Anjali  22.0   74.0     ME
# 4   Kiran   NaN   88.0    CSE

# %%
df.isna()   #to see in t or f value
# Out:
#     Name    Age  Marks  Branch
# 0  False  False  False   False
# 1  False   True  False   False
# 2  False  False   True    True
# 3  False  False  False   False
# 4  False   True  False   False

# %%
df.isna().sum()  #take sum of the in the present noul value or not
# Out:
# Name      0
# Age       2
# Marks     1
# Branch    1
# dtype: int64

# %%
# removingthe mising data

# %%
df.dropna() #if  row contains all value it retunor else al table drope
# Out:
#      Name   Age  Marks Branch
# 0  Naveen  20.0   85.0    CSE
# 3  Anjali  22.0   74.0     ME

# %%
df.dropna(thresh=4)  #means 4 non nul valuse
# Out:
#      Name   Age  Marks Branch
# 0  Naveen  20.0   85.0    CSE
# 3  Anjali  22.0   74.0     ME

# %%
# filing mising data

# %%
df.fillna(0)
# Out:
#      Name   Age  Marks Branch
# 0  Naveen  20.0   85.0    CSE
# 1   Rahul   0.0   78.0    ECE
# 2   Priya  19.0    0.0      0
# 3  Anjali  22.0   74.0     ME
# 4   Kiran   0.0   88.0    CSE

# %%
values={"Age":10, "Marks":50,"Branch":"mba"}
df.fillna(value=values)
# Out:
#      Name   Age  Marks Branch
# 0  Naveen  20.0   85.0    CSE
# 1   Rahul  10.0   78.0    ECE
# 2   Priya  19.0   50.0    mba
# 3  Anjali  22.0   74.0     ME
# 4   Kiran  10.0   88.0    CSE
