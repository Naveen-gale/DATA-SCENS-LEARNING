# %%
# how to Series works
import numpy as np
import pandas as pd

# %%
lables=['a','b', 'c']
list=[10, 20 ,30]
arr=np.array([10,20 ,30])
d={
 1:10,2:20,3:30

}

# %%
pd.Series(list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(list,index=lables)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
# data fromam: combine the multiple series called df
